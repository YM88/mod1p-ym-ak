# %%
# standard imports

# print everything
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import sys
print('python:', sys.version_info[:3])

import numpy as np
print('numpy:', np.__version__)

import pandas as pd
print('pandas:', pd.__version__)


import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
print('seaborn:', sns.__version__)
plt.style.use('ggplot')
# Out:
# python: (3, 7, 3)
# numpy: 1.16.4
# pandas: 0.24.2
# seaborn: 0.9.0

# %% [markdown]
# Data collected from *Box Office Mojo*:
#
# https://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=2010&p=.htm
#
# shows **3387** movie *titles* from *2010* to *2018*
# with **3359** doemstic gross values and **2032** foreign gross values.

# %%
#importing the dataframe from box office mojo
bom_movie_gross_df = pd.read_csv('data/bom.movie_gross.csv.gz')
bom_movie_gross_df.head()
bom_movie_gross_df.info()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# since the tn_movie_budgets_df has production budget, we will use that data set instead.

# %% [markdown]
# # 2. IMDB Data
#
# Data gathered from [IMDB](https://www.imdb.com/interfaces/)

# %% [markdown]
# ## name values like actor/director to be taken out from this dataset
#
# **name.basics.tsv.gz** – Contains the following information for names:
# - nconst (string) - alphanumeric unique identifier of the name/person
# - primaryName (string)– name by which the person is most often credited
# - birthYear – in YYYY format
# - deathYear – in YYYY format if applicable, else '\N'
# - primaryProfession (array of strings)– the top-3 professions of the person
# - knownForTitles (array of tconsts) – titles the person is known for

# %%
pd.read_csv('data/imdb.name.basics.csv.gz').head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %% [markdown]
# **title.akas.tsv.gz** - Contains the following information for titles:
#
# - titleId (string) - a tconst, an alphanumeric unique identifier of the title
# - ordering (integer) – a number to uniquely identify rows for a given titleId
# - title (string) – the localized title
# - region (string) - the region for this version of the title
# - language (string) - the language of the title
# - types (array) - Enumerated set of attributes for this alternative title. One or more of the following: "alternative", "dvd", "festival", "tv", "video", "working", "original", "imdbDisplay". New values may be added in the future without warning
# - attributes (array) - Additional terms to describe this alternative title, not enumerated
# - isOriginalTitle (boolean) – 0: not original title; 1: original title

# %%
#checking the dataframe, won't be using this one
pd.read_csv('data/imdb.title.akas.csv.gz').head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %% [markdown]
# ## Genre & title name info to be merged from this dataframe
# **title.basics.tsv.gz** - Contains the following information for titles:
# - tconst (string) - alphanumeric unique identifier of the title
# - titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# - primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# - originalTitle (string) - original title, in the original language
# - isAdult (boolean) - 0: non-adult title; 1: adult title
# - startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
# - endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
# - runtimeMinutes – primary runtime of the title, in minutes
# - genres (string array) – includes up to three genres associated with the title

# %%
pd.read_csv('data/imdb.title.basics.csv.gz').head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basics_df = pd.read_csv('data/imdb.title.basics.csv.gz', 
                                   usecols = ['tconst', 
                                              'original_title', 
                                              'start_year', 
                                             'genres'])
imdb_title_basics_df.head()
imdb_title_basics_df.info()
# Out:
#       tconst              original_title  start_year                genres
# 0  tt0063540                   Sunghursh        2013    Action,Crime,Drama
# 1  tt0066787             Ashad Ka Ek Din        2019       Biography,Drama
# 2  tt0069049  The Other Side of the Wind        2018                 Drama
# 3  tt0069204             Sabse Bada Sukh        2018          Comedy,Drama
# 4  tt0100275       La Telenovela Errante        2017  Comedy,Drama,Fantasy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 4 columns):
# tconst            146144 non-null object
# original_title    146123 non-null object
# start_year        146144 non-null int64
# genres            140736 non-null object
# dtypes: int64(1), object(3)
# memory usage: 4.5+ MB

# %%
#to get a list of all mentioned genres
all_genres = set()
genre_series = imdb_title_basics_df.genres

for row in genre_series:
    try:
        for genre in row.split(','):
            all_genres.add(genre)
    except:
        continue
all_genres = list(all_genres)

#created separate columns for the genres
for genre in all_genres:
    imdb_title_basics_df[genre] = imdb_title_basics_df.genres.apply(lambda x: genre in str(x).split(','))

imdb_title_basics_df.columns
imdb_title_basics_df.head()
# Out:
# Index(['tconst', 'original_title', 'start_year', 'genres', 'Talk-Show',
#        'Game-Show', 'Western', 'Reality-TV', 'News', 'Sci-Fi', 'Biography',
#        'Crime', 'Fantasy', 'Horror', 'Sport', 'History', 'War', 'Action',
#        'Family', 'Music', 'Animation', 'Romance', 'Mystery', 'Documentary',
#        'Short', 'Adult', 'Comedy', 'Drama', 'Thriller', 'Musical',
#        'Adventure'],
#       dtype='object')
#       tconst              original_title  start_year                genres  \
# 0  tt0063540                   Sunghursh        2013    Action,Crime,Drama
# 1  tt0066787             Ashad Ka Ek Din        2019       Biography,Drama
# 2  tt0069049  The Other Side of the Wind        2018                 Drama
# 3  tt0069204             Sabse Bada Sukh        2018          Comedy,Drama
# 4  tt0100275       La Telenovela Errante        2017  Comedy,Drama,Fantasy
#
#    Talk-Show  Game-Show  Western  Reality-TV   News  Sci-Fi  ...  Romance  \
# 0      False      False    False       False  False   False  ...    False
# 1      False      False    False       False  False   False  ...    False
# 2      False      False    False       False  False   False  ...    False
# 3      False      False    False       False  False   False  ...    False
# 4      False      False    False       False  False   False  ...    False
#
#    Mystery  Documentary  Short  Adult  Comedy  Drama  Thriller  Musical  \
# 0    False        False  False  False   False   True     False    False
# 1    False        False  False  False   False   True     False    False
# 2    False        False  False  False   False   True     False    False
# 3    False        False  False  False    True   True     False    False
# 4    False        False  False  False    True   True     False    False
#
#    Adventure
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 31 columns]

# %% [markdown]
# ## director and writer info to be extracted from this one
#
# **title.crew.tsv.gz** – Contains the director and writer information for all the titles in IMDb.
#
# Fields include:
# - tconst (string) - alphanumeric unique identifier of the title
# - directors (array of nconsts) - director(s) of the given title
# - writers (array of nconsts) – writer(s) of the given title

# %%
pd.read_csv('data/imdb.title.crew.csv.gz').head()
pd.read_csv('data/imdb.title.crew.csv.gz').info()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# **title.principals.tsv.gz** – Contains the principal cast/crew for titles
# - tconst (string) - alphanumeric unique identifier of the title
# - ordering (integer) – a number to uniquely identify rows for a given titleId
# - nconst (string) - alphanumeric unique identifier of the name/person
# - category (string) - the category of job that person was in
# - job (string) - the specific job title if applicable, else '\N'
# - characters (string) - the name of the character played if applicable, else '\N'

# %%
pd.read_csv('data/imdb.title.principals.csv.gz').head()
pd.read_csv('data/imdb.title.principals.csv.gz').info()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
imdb_title_principals_df = pd.read_csv('data/imdb.title.principals.csv.gz', 
                                       usecols = ['tconst', 
                                                  'nconst', 
                                                  'category'])

# %%
imdb_title_principals_df.head()
# Out:
#       tconst     nconst  category
# 0  tt0111414  nm0246005     actor
# 1  tt0111414  nm0398271  director
# 2  tt0111414  nm3739909  producer
# 3  tt0323808  nm0059247    editor
# 4  tt0323808  nm3579312   actress

# %% [markdown]
# **title.ratings.tsv.gz** – Contains the IMDb rating and votes information for titles
# - tconst (string) - alphanumeric unique identifier of the title
# - averageRating – weighted average of all the individual user ratings
# - numVotes - number of votes the title has received

# %%
pd.read_csv('data/imdb.title.ratings.csv.gz').head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_title_ratings = pd.read_csv('data/imdb.title.ratings.csv.gz')
imdb_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#creating the master imdb dataframe via tconst. values in title.basics, title.ratings

# %%
imdb_review_genres_df = pd.merge(imdb_title_basics_df, imdb_title_ratings, 
             left_on = 'tconst', 
             right_on = 'tconst',
             how = 'inner')

# %%
imdb_title_basics_df.info()
print('\n')
imdb_title_ratings.info()
imdb_review_genres_df.head()
imdb_review_genres_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 31 columns):
# tconst            146144 non-null object
# original_title    146123 non-null object
# start_year        146144 non-null int64
# genres            140736 non-null object
# Talk-Show         146144 non-null bool
# Game-Show         146144 non-null bool
# Western           146144 non-null bool
# Reality-TV        146144 non-null bool
# News              146144 non-null bool
# Sci-Fi            146144 non-null bool
# Biography         146144 non-null bool
# Crime             146144 non-null bool
# Fantasy           146144 non-null bool
# Horror            146144 non-null bool
# Sport             146144 non-null bool
# History           146144 non-null bool
# War               146144 non-null bool
# Action            146144 non-null bool
# Family            146144 non-null bool
# Music             146144 non-null bool
# Animation         146144 non-null bool
# Romance           146144 non-null bool
# Mystery           146144 non-null bool
# Documentary       146144 non-null bool
# Short             146144 non-null bool
# Adult             146144 non-null bool
# Comedy            146144 non-null bool
# Drama             146144 non-null bool
# Thriller          146144 non-null bool
# Musical           146144 non-null bool
# Adventure         146144 non-null bool
# dtypes: bool(27), int64(1), object(3)
# memory usage: 8.2+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
#       tconst              original_title  start_year                genres  \
# 0  tt0063540                   Sunghursh        2013    Action,Crime,Drama
# 1  tt0066787             Ashad Ka Ek Din        2019       Biography,Drama
# 2  tt0069049  The Other Side of the Wind        2018                 Drama
# 3  tt0069204             Sabse Bada Sukh        2018          Comedy,Drama
# 4  tt0100275       La Telenovela Errante        2017  Comedy,Drama,Fantasy
#
#    Talk-Show  Game-Show  Western  Reality-TV   News  Sci-Fi  ...  Documentary  \
# 0      False      False    False       False  False   False  ...        False
# 1      False      False    False       False  False   False  ...        False
# 2      False      False    False       False  False   False  ...        False
# 3      False      False    False       False  False   False  ...        False
# 4      False      False    False       False  False   False  ...        False
#
#    Short  Adult  Comedy  Drama  Thriller  Musical  Adventure  averagerating  \
# 0  False  False   False   True     False    False      False            7.0
# 1  False  False   False   True     False    False      False            7.2
# 2  False  False   False   True     False    False      False            6.9
# 3  False  False    True   True     False    False      False            6.1
# 4  False  False    True   True     False    False      False            6.5
#
#    numvotes
# 0        77
# 1        43
# 2      4517
# 3        13
# 4       119
#
# [5 rows x 33 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 33 columns):
# tconst            73856 non-null object
# original_title    73856 non-null object
# start_year        73856 non-null int64
# genres            73052 non-null object
# Talk-Show         73856 non-null bool
# Game-Show         73856 non-null bool
# Western           73856 non-null bool
# Reality-TV        73856 non-null bool
# News              73856 non-null bool
# Sci-Fi            73856 non-null bool
# Biography         73856 non-null bool
# Crime             73856 non-null bool
# Fantasy           73856 non-null bool
# Horror            73856 non-null bool
# Sport             73856 non-null bool
# History           73856 non-null bool
# War               73856 non-null bool
# Action            73856 non-null bool
# Family            73856 non-null bool
# Music             73856 non-null bool
# Animation         73856 non-null bool
# Romance           73856 non-null bool
# Mystery           73856 non-null bool
# Documentary       73856 non-null bool
# Short             73856 non-null bool
# Adult             73856 non-null bool
# Comedy            73856 non-null bool
# Drama             73856 non-null bool
# Thriller          73856 non-null bool
# Musical           73856 non-null bool
# Adventure         73856 non-null bool
# averagerating     73856 non-null float64
# numvotes          73856 non-null int64
# dtypes: bool(27), float64(1), int64(2), object(3)
# memory usage: 5.8+ MB

# %% [markdown]
# # Rotten Tomatoes Data
# Data is gathered from [Kaggle](https://www.kaggle.com/rpnuser8182/rotten-tomatoes)
#
# **rt.movie_info.tsv.gz** - Contains basic information about movies from rotten tomatoes:
#
# - idtable - key: a primary key that can be used to join with the reviews file.
# - synopsis - synopsis of the movie
# - rating - Rotten Tomatoes rating for the movie
# - genre - genre(s)
# - director - director(s)
# - writer - writers(s)
# - theater_datedate - released to theaters
# - dvd_datedate - released to dvd
# - currency - currency of the box office value
# - box_office - box office earnings
# - runtime - minutes of runtime
# - studio - production studio

# %%
pd.read_csv('data/rt.movie_info.tsv.gz', sep = '\t').head(100)
pd.read_csv('data/rt.movie_info.tsv.gz', sep = '\t').info()
# Out:
#      id                                           synopsis rating  \
# 0     1  This gritty, fast-paced, and innovative police...      R
# 1     3  New York City, not-too-distant-future: Eric Pa...      R
# 2     5  Illeana Douglas delivers a superb performance ...      R
# 3     6  Michael Douglas runs afoul of a treacherous su...      R
# 4     7                                                NaN     NR
# 5     8  The year is 1942. As the Allies unite overseas...     PG
# 6    10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7    13  Stewart Kane, an Irishman living in the Austra...      R
# 8    14  "Love Ranch" is a bittersweet love story that ...      R
# 9    15  When a diamond expedition in the Congo is lost...  PG-13
# 10   17                                                NaN    NaN
# 11   18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 12   19  While Microsoft may be the biggest software co...     NR
# 13   20  Rachel (Britt Ekland) is an Amish girl who rej...  PG-13
# 14   21  Old-school comic Rodney "I get no respect" Dan...      R
# 15   22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 16   23  A fictional film set in the alluring world of ...      R
# 17   24  Three young boys discover a stranded Russian s...     PG
# 18   25  From ancient Japan's most enduring tale, the e...  PG-13
# 19   26  A comic series of short vignettes build on one...      R
# 20   27                                                NaN     NR
# 21   28  Elvis goes Hawaiian for the second time in thi...      G
# 22   29  This futuristic adventure stars Lee Majors as ...     PG
# 23   33  Howard W. Campbell Jr. (Nick Nolte) is an Amer...      R
# 24   34  Director John Woo brings Hong Kong-style marti...  PG-13
# 25   35  In this film, conjoined twins Blake and Franci...      R
# 26   38  You'd think they would know better from their ...      R
# 27   39  A group of stoners at a rock festival is stalk...      R
# 28   40  John Sayles' Casa de los Babys tells the tale ...      R
# 29   41  Ken Loach directs Sweet Sixteen, a gritty dram...      R
# ..  ...                                                ...    ...
# 70   88  This gay-lifestyle comedy features aspiring ph...      R
# 71   89  Now hear this. The studio that gave the cinema...     NR
# 72   90  No, No, Nanette was the second film version of...     NR
# 73   92  A wonderfully atmospheric outing from Hammer F...     NR
# 74   93                                      "Garbo Laughs      R
# 75   94  In this gritty drama, a woman discovers that h...      R
# 76   95  BLEED FOR THIS is the incredible true story of...      R
# 77   96  A gang of suburban slackers spend an evening h...      R
# 78   98  This video features the story of a mother tell...     NR
# 79   99  A woman finds herself attempting to foil one o...  PG-13
# 80  100  Four old college friends in their forties come...     NR
# 81  101  After getting booted out of his latest manager...      R
# 82  102  Aging, small town attorney Mac McClain (Matthe...  PG-13
# 83  104  In 1981, Ronald Biggs was kidnapped by agents ...     NR
# 84  105  Mark Twain's classic tale of comedy and advent...     NR
# 85  106  Three dope-smoking ex-convicts live among frie...      R
# 86  108  A picture-perfect family moves into an upscale...      R
# 87  109                                                NaN     NR
# 88  110  This is director Frank Capra's classic bitters...     PG
# 89  111  Detective Rem Macy (Tom Berenger) is investiga...      R
# 90  115  "Toy Story 2" is the exciting, all-new sequel ...      G
# 91  116  Jane Campion's first film, Sweetie, is the biz...      R
# 92  118  For four years, the courageous crew of the NSE...     PG
# 93  119  Brian DePalma directed this taut thriller, set...      R
# 94  120  Artist Christopher Pride has just been commiss...     PG
# 95  121  Comic actor and former Saturday Night Live sto...  PG-13
# 96  123  The second of Robert Youngson's compilations o...     NR
# 97  124  In present-day London, twelve-year-old Quinn w...  PG-13
# 98  126  Following up from their success with Project A...     NR
# 99  127  A tortured man finds himself caught in a middl...      R
#
#                                                 genre  \
# 0                 Action and Adventure|Classics|Drama
# 1                   Drama|Science Fiction and Fantasy
# 2                   Drama|Musical and Performing Arts
# 3                          Drama|Mystery and Suspense
# 4                                       Drama|Romance
# 5                               Drama|Kids and Family
# 6                                              Comedy
# 7                                               Drama
# 8                                               Drama
# 9   Action and Adventure|Mystery and Suspense|Scie...
# 10                                                NaN
# 11                                        Documentary
# 12                       Documentary|Special Interest
# 13                              Classics|Comedy|Drama
# 14                                             Comedy
# 15                  Comedy|Drama|Mystery and Suspense
# 16                                              Drama
# 17                  Action and Adventure|Comedy|Drama
# 18  Action and Adventure|Drama|Science Fiction and...
# 19  Art House and International|Comedy|Drama|Music...
# 20                        Musical and Performing Arts
# 21  Classics|Comedy|Musical and Performing Arts|Ro...
# 22  Action and Adventure|Drama|Science Fiction and...
# 23    Action and Adventure|Drama|Mystery and Suspense
# 24          Action and Adventure|Mystery and Suspense
# 25                                              Drama
# 26  Art House and International|Classics|Horror|My...
# 27                                             Horror
# 28                                              Drama
# 29                                              Drama
# ..                                                ...
# 70                                     Comedy|Romance
# 71                 Comedy|Musical and Performing Arts
# 72          Drama|Musical and Performing Arts|Romance
# 73        Art House and International|Classics|Horror
# 74                      Classics|Comedy|Drama|Romance
# 75  Art House and International|Drama|Mystery and ...
# 76                           Drama|Sports and Fitness
# 77                                       Comedy|Drama
# 78                                       Comedy|Drama
# 79                                     Comedy|Romance
# 80                                       Comedy|Drama
# 81                            Comedy|Drama|Television
# 82                         Drama|Mystery and Suspense
# 83          Action and Adventure|Mystery and Suspense
# 84         Animation|Kids and Family|Special Interest
# 85                                             Comedy
# 86                       Comedy|Drama|Kids and Family
# 87                                       Comedy|Drama
# 88  Classics|Comedy|Drama|Kids and Family|Science ...
# 89                         Drama|Mystery and Suspense
# 90  Animation|Comedy|Kids and Family|Science Ficti...
# 91           Art House and International|Comedy|Drama
# 92                 Comedy|Science Fiction and Fantasy
# 93    Action and Adventure|Drama|Mystery and Suspense
# 94                                     Comedy|Romance
# 95                                     Comedy|Romance
# 96                   Classics|Comedy|Special Interest
# 97   Action and Adventure|Science Fiction and Fantasy
# 98  Action and Adventure|Art House and Internation...
# 99                  Drama|Horror|Mystery and Suspense
#
#                          director  \
# 0                William Friedkin
# 1                David Cronenberg
# 2                  Allison Anders
# 3                  Barry Levinson
# 4                  Rodney Bennett
# 5                     Jay Russell
# 6                     Jake Kasdan
# 7                    Ray Lawrence
# 8                 Taylor Hackford
# 9                  Frank Marshall
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13               William Friedkin
# 14                  Peter Baldwin
# 15            George Hickenlooper
# 16                            NaN
# 17                 Rick Rosenthal
# 18               Carl Erik Rinsch
# 19                   Jim Jarmusch
# 20                            NaN
# 21                            NaN
# 22                   Martyn Burke
# 23                   Keith Gordon
# 24                       John Woo
# 25                 Michael Polish
# 26                 Roy Ward Baker
# 27                 David Arquette
# 28                    John Sayles
# 29                      Ken Loach
# ..                            ...
# 70                            NaN
# 71                            NaN
# 72                 Herbert Wilcox
# 73                   John Gilling
# 74                 Ernst Lubitsch
# 75                   Cheryl Dunye
# 76                    Ben Younger
# 77              Richard Linklater
# 78                      Alan Hale
# 79                            NaN
# 80  Willem van de Sande Bakhuyzen
# 81              Tommy Lee Wallace
# 82                   Gary Wheeler
# 83                  Lech Majewski
# 84                            NaN
# 85               Mike Clattenburg
# 86                  Derrick Borte
# 87                    Mike Figgis
# 88                    Frank Capra
# 89                            NaN
# 90                  John Lasseter
# 91                   Jane Campion
# 92                   Dean Parisot
# 93                  Brian DePalma
# 94                    Jerry Lewis
# 95                Thomas Schlamme
# 96                Robert Youngson
# 97                     Rob Bowman
# 98              Sammo Hung Kam-Bo
# 99                    Adrian Lyne
#
#                                                writer  theater_date  \
# 0                                      Ernest Tidyman   Oct 9, 1971
# 1                        David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                      Allison Anders  Sep 13, 1996
# 3                     Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                        Giles Cooper           NaN
# 5                                     Gail Gilchriest   Mar 3, 2000
# 6                                          Mike White  Jan 11, 2002
# 7                    Raymond Carver|Beatrix Christian  Apr 27, 2006
# 8                                       Mark Jacobson  Jun 30, 2010
# 9                                John Patrick Shanley   Jun 9, 1995
# 10                                                NaN           NaN
# 11                                       Robert Zullo           NaN
# 12                                                NaN  Aug 23, 2002
# 13        Sidney Michaels|Arnold Schulman|Norman Lear  Dec 22, 1968
# 14                     Rodney Dangerfield|Harry Basil  Jan 31, 1997
# 15                                      Norman Snider  Dec 17, 2010
# 16                                                NaN  Dec 20, 2013
# 17  Sheldon Lettich|Michael Nankin|Alan Jay Glueckman   Nov 6, 1987
# 18                         Chris Morgan|Hossein Amini  Dec 25, 2013
# 19                                       Jim Jarmusch  May 14, 2004
# 20                                                NaN           NaN
# 21                       Allan Weiss|Anthony Lawrence  Jun 15, 1966
# 22                                                NaN   Apr 1, 1981
# 23                                                NaN   Nov 1, 1996
# 24  William Goldman|John Logan|David Marconi|Micha...  Dec 31, 2000
# 25                         Michael Polish|Mark Polish  Jul 30, 1999
# 26                           Anthony Hinds|John Elder  Dec 23, 1970
# 27                          David Arquette|Joe Harris  Apr 20, 2007
# 28                                        John Sayles  Sep 19, 2003
# 29                                       Paul Laverty  May 16, 2003
# ..                                                ...           ...
# 70                                                NaN  Jul 24, 1998
# 71                                                NaN           NaN
# 72                                        Ken Englund           NaN
# 73               Anthony Hinds|John Elder|Peter Bryan   Jan 1, 1966
# 74  Charles Brackett|Billy Wilder|Walter Reisch|Me...   Nov 3, 1939
# 75                      Catherine Crouch|Cheryl Dunye  Jun 23, 2001
# 76                                        Ben Younger  Nov 18, 2016
# 77                                      Eric Bogosian           NaN
# 78                                   Beulah Marie Dix           NaN
# 79                                                NaN  Dec 20, 2002
# 80                                                NaN           NaN
# 81                                                NaN  Jul 11, 1992
# 82  Mark Freiburger|Gary Wheeler|Robert Whitlow|Ma...           NaN
# 83                                                NaN           NaN
# 84                                                NaN           NaN
# 85                        Mike Clattenburg|Robb Wells   Jun 6, 2006
# 86                                      Derrick Borte  Apr 16, 2010
# 87                                                NaN           NaN
# 88        Frank Capra|Frances Goodrich|Albert Hackett  Dec 25, 1946
# 89                                                NaN  Nov 29, 2001
# 90  Doug Chamberlain|Rita Hsiao|Doug Chamberlin|Ch...  Nov 24, 1999
# 91                            Gerard Lee|Jane Campion  Sep 10, 1989
# 92                                      Robert Gordon  Dec 25, 1999
# 93                          Brian DePalma|David Koepp   Aug 7, 1998
# 94                                                NaN           NaN
# 95  Mike Myers|Robbie Fox|Carrie Fisher|Neil Mulla...  Jul 30, 1993
# 96                                    Robert Youngson  Mar 31, 1968
# 97  Terry Hayes|Kevin Peterka|Gregg Chabot|Matthew...  Jul 12, 2002
# 98                                                NaN  Aug 17, 1984
# 99                     Bruce Joel Rubin|Joel Blasberg   Nov 2, 1990
#
#         dvd_date currency  box_office      runtime  \
# 0   Sep 25, 2001      NaN         NaN  104 minutes
# 1    Jan 1, 2013        $     600,000  108 minutes
# 2   Apr 18, 2000      NaN         NaN  116 minutes
# 3   Aug 27, 1997      NaN         NaN  128 minutes
# 4            NaN      NaN         NaN  200 minutes
# 5   Jul 11, 2000      NaN         NaN   95 minutes
# 6   Jun 18, 2002        $  41,032,915   82 minutes
# 7    Oct 2, 2007        $     224,114  123 minutes
# 8    Nov 9, 2010        $     134,904  117 minutes
# 9   Jul 27, 1999      NaN         NaN  108 minutes
# 10           NaN      NaN         NaN          NaN
# 11           NaN      NaN         NaN          NaN
# 12  Sep 30, 2003      NaN         NaN   90 minutes
# 13  May 20, 2008      NaN         NaN   97 minutes
# 14  Sep 20, 1999      NaN         NaN  106 minutes
# 15   Apr 5, 2011        $   1,039,869  108 minutes
# 16  Mar 18, 2014        $  99,165,609  129 minutes
# 17   Mar 8, 2005      NaN         NaN   98 minutes
# 18   Apr 1, 2014        $  20,518,224  127 minutes
# 19  Sep 21, 2004        $   1,971,135   96 minutes
# 20           NaN      NaN         NaN          NaN
# 21   Jan 7, 2003      NaN         NaN   90 minutes
# 22  May 10, 2011      NaN         NaN  101 minutes
# 23  Aug 22, 2000      NaN         NaN  114 minutes
# 24   Nov 7, 2000      NaN         NaN  123 minutes
# 25  Jan 18, 2000      NaN         NaN  110 minutes
# 26   Aug 7, 2001      NaN         NaN   96 minutes
# 27  Oct 30, 2007      NaN         NaN   97 minutes
# 28  Apr 13, 2004        $     312,136   95 minutes
# 29   Oct 7, 2003        $     201,010  106 minutes
# ..           ...      ...         ...          ...
# 70  Dec 22, 1998      NaN         NaN   92 minutes
# 71           NaN      NaN         NaN  123 minutes
# 72           NaN      NaN         NaN   96 minutes
# 73   Nov 2, 1999      NaN         NaN   90 minutes
# 74   Sep 5, 2005      NaN         NaN  110 minutes
# 75  Jul 16, 2002      NaN         NaN   90 minutes
# 76  Feb 14, 2017        $   5,051,927  116 minutes
# 77           NaN      NaN         NaN  118 minutes
# 78           NaN      NaN         NaN  104 minutes
# 79  Apr 29, 2003        $  93,300,000  102 minutes
# 80           NaN      NaN         NaN  108 minutes
# 81  Apr 21, 1993      NaN         NaN   90 minutes
# 82           NaN      NaN         NaN  101 minutes
# 83           NaN      NaN         NaN   90 minutes
# 84           NaN      NaN         NaN   60 minutes
# 85  Apr 22, 2008      NaN         NaN   95 minutes
# 86  Aug 10, 2010        $   1,000,000   93 minutes
# 87           NaN      NaN         NaN   55 minutes
# 88  Sep 19, 1995      NaN         NaN  135 minutes
# 89   Mar 5, 2002      NaN         NaN  101 minutes
# 90  Oct 17, 2000      NaN         NaN   92 minutes
# 91  Oct 24, 2006      NaN         NaN   97 minutes
# 92   May 2, 2000      NaN         NaN  102 minutes
# 93  Feb 16, 1999      NaN         NaN  107 minutes
# 94           NaN      NaN         NaN  109 minutes
# 95   Jun 1, 1999      NaN         NaN   93 minutes
# 96   Jun 5, 2007      NaN         NaN   99 minutes
# 97  Nov 19, 2002        $  42,929,971  101 minutes
# 98  Aug 14, 2001      NaN         NaN   98 minutes
# 99  Sep 14, 2010      NaN         NaN  113 minutes
#
#                                   studio
# 0                                    NaN
# 1                      Entertainment One
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                  Warner Bros. Pictures
# 6                     Paramount Pictures
# 7                 Sony Pictures Classics
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11            Showtime Documentary Films
# 12                 Seventh Art Releasing
# 13                                   NaN
# 14                                   NaN
# 15                          ATO Pictures
# 16                         Sony Pictures
# 17                                   NaN
# 18                    Universal Pictures
# 19                                   MGM
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                    Paramount Pictures
# 25                                   NaN
# 26                                   NaN
# 27  After Dark Films/Freestyle Releasing
# 28                                   NaN
# 29                      Lions Gate Films
# ..                                   ...
# 70                                   NaN
# 71                                   NaN
# 72                                   NaN
# 73                                   NaN
# 74                                   NaN
# 75                                   NaN
# 76                       Open Road Films
# 77                                   NaN
# 78                                   NaN
# 79                          Warner Bros.
# 80                                   NaN
# 81                                   NaN
# 82                                   Fox
# 83                                   NaN
# 84                                   NaN
# 85                    Screen Media Films
# 86                  Roadside Attractions
# 87                                   NaN
# 88                                   NaN
# 89                                   NaN
# 90                  Buena Vista Pictures
# 91                                   NaN
# 92                        DreamWorks SKG
# 93                                   NaN
# 94                                   NaN
# 95                                   NaN
# 96                                   NaN
# 97        Buena Vista Distribution Compa
# 98                                   NaN
# 99                                   NaN
#
# [100 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.3+ KB

# %% [markdown]
# **rt.movie_info.tsv.gz** - Contains basic information about movie reviews from rotten tomatoes:
#
# - id: table foreign key; used to join with movie_info.tsv
# - reviews: text of critic reviews
# - rating: rating
# - fresh: freshness of review - fresh or rotten
# - critic: critic name
# - top_critic: if critic is considered a 'top critic' 1 or 0
# - publisher: publisher or review
# - date: date of review

# %%
pd.read_csv('data/rt.reviews.tsv.gz', sep = '\t', encoding='latin-1').head()
pd.read_csv('data/rt.reviews.tsv.gz', sep = '\t', encoding='latin-1').info()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
pd.read_csv('data/tmdb.movies.csv.gz').head()
pd.read_csv('data/tmdb.movies.csv.gz').info()
#we can use popularity
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
pd.read_csv('data/tn.movie_budgets.csv.gz').head()
pd.read_csv('data/tn.movie_budgets.csv.gz').info()
tn_movie_budgets_df = pd.read_csv('data/tn.movie_budgets.csv.gz')
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB

# %%
def convert_to_numeric(some_object):
    '''This function converts formatted numbers 
     with $ sign and thousand separaters to integers.'''
    return int(some_object.lstrip('$').replace(',',''))

#convert formatted numbers to numeric values
tn_movie_budgets_df.iloc[:, 3:] = tn_movie_budgets_df.iloc[:, 3:].applymap(convert_to_numeric)
#remove id column
tn_movie_budgets_df.drop('id', inplace=True, axis=1)
#keep only the year from the release_date column
tn_movie_budgets_df['year'] = tn_movie_budgets_df.release_date.apply(lambda x: x[-4:]).astype(int)
tn_movie_budgets_df.drop('release_date', inplace=True, axis=1)
tn_movie_budgets_df.head()
tn_movie_budgets_df.info()
# Out:
#                                          movie  production_budget  \
# 0                                       Avatar          425000000
# 1  Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                 Dark Phoenix          350000000
# 3                      Avengers: Age of Ultron          330600000
# 4            Star Wars Ep. VIII: The Last Jedi          317000000
#
#    domestic_gross  worldwide_gross  year
# 0       760507625       2776345279  2009
# 1       241063875       1045663875  2011
# 2        42762350        149762350  2019
# 3       459005868       1403013963  2015
# 4       620181382       1316721747  2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
# movie                5782 non-null object
# production_budget    5782 non-null int64
# domestic_gross       5782 non-null int64
# worldwide_gross      5782 non-null int64
# year                 5782 non-null int32
# dtypes: int32(1), int64(3), object(1)
# memory usage: 203.4+ KB

# %%
genre_financial_df = pd.merge(imdb_title_basics_df, tn_movie_budgets_df, 
         left_on = 'original_title', 
        right_on = 'movie', 
        how = 'inner')

# %%
genre_financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3537 entries, 0 to 3536
# Data columns (total 36 columns):
# tconst               3537 non-null object
# original_title       3537 non-null object
# start_year           3537 non-null int64
# genres               3473 non-null object
# Talk-Show            3537 non-null bool
# Game-Show            3537 non-null bool
# Western              3537 non-null bool
# Reality-TV           3537 non-null bool
# News                 3537 non-null bool
# Sci-Fi               3537 non-null bool
# Biography            3537 non-null bool
# Crime                3537 non-null bool
# Fantasy              3537 non-null bool
# Horror               3537 non-null bool
# Sport                3537 non-null bool
# History              3537 non-null bool
# War                  3537 non-null bool
# Action               3537 non-null bool
# Family               3537 non-null bool
# Music                3537 non-null bool
# Animation            3537 non-null bool
# Romance              3537 non-null bool
# Mystery              3537 non-null bool
# Documentary          3537 non-null bool
# Short                3537 non-null bool
# Adult                3537 non-null bool
# Comedy               3537 non-null bool
# Drama                3537 non-null bool
# Thriller             3537 non-null bool
# Musical              3537 non-null bool
# Adventure            3537 non-null bool
# movie                3537 non-null object
# production_budget    3537 non-null int64
# domestic_gross       3537 non-null int64
# worldwide_gross      3537 non-null int64
# year                 3537 non-null int32
# dtypes: bool(27), int32(1), int64(4), object(4)
# memory usage: 355.8+ KB

# %%
genre_financial_df = genre_financial_df.loc[(genre_financial_df.year > 2009) & #filtering out movies for 2010-2018
                                            (genre_financial_df.year <2019)]

# %%
genre_financial_df.head()
genre_financial_df.info()
# Out:
#       tconst original_title  start_year                   genres  Talk-Show  \
# 0  tt0249516     Foodfight!        2012  Action,Animation,Comedy      False
# 2  tt0326592  The Overnight        2010                      NaN      False
# 3  tt3844362  The Overnight        2015           Comedy,Mystery      False
# 4  tt0337692    On the Road        2012  Adventure,Drama,Romance      False
# 5  tt2404548    On the Road        2011                    Drama      False
#
#    Game-Show  Western  Reality-TV   News  Sci-Fi  ...  Comedy  Drama  \
# 0      False    False       False  False   False  ...    True  False
# 2      False    False       False  False   False  ...   False  False
# 3      False    False       False  False   False  ...    True  False
# 4      False    False       False  False   False  ...   False   True
# 5      False    False       False  False   False  ...   False   True
#
#    Thriller  Musical  Adventure          movie  production_budget  \
# 0     False    False      False     Foodfight!           45000000
# 2     False    False      False  The Overnight             200000
# 3     False    False      False  The Overnight             200000
# 4     False    False       True    On the Road           25000000
# 5     False    False      False    On the Road           25000000
#
#    domestic_gross  worldwide_gross  year
# 0               0            73706  2012
# 2         1109808          1165996  2015
# 3         1109808          1165996  2015
# 4          720828          9313302  2013
# 5          720828          9313302  2013
#
# [5 rows x 36 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2442 entries, 0 to 3516
# Data columns (total 36 columns):
# tconst               2442 non-null object
# original_title       2442 non-null object
# start_year           2442 non-null int64
# genres               2415 non-null object
# Talk-Show            2442 non-null bool
# Game-Show            2442 non-null bool
# Western              2442 non-null bool
# Reality-TV           2442 non-null bool
# News                 2442 non-null bool
# Sci-Fi               2442 non-null bool
# Biography            2442 non-null bool
# Crime                2442 non-null bool
# Fantasy              2442 non-null bool
# Horror               2442 non-null bool
# Sport                2442 non-null bool
# History              2442 non-null bool
# War                  2442 non-null bool
# Action               2442 non-null bool
# Family               2442 non-null bool
# Music                2442 non-null bool
# Animation            2442 non-null bool
# Romance              2442 non-null bool
# Mystery              2442 non-null bool
# Documentary          2442 non-null bool
# Short                2442 non-null bool
# Adult                2442 non-null bool
# Comedy               2442 non-null bool
# Drama                2442 non-null bool
# Thriller             2442 non-null bool
# Musical              2442 non-null bool
# Adventure            2442 non-null bool
# movie                2442 non-null object
# production_budget    2442 non-null int64
# domestic_gross       2442 non-null int64
# worldwide_gross      2442 non-null int64
# year                 2442 non-null int32
# dtypes: bool(27), int32(1), int64(4), object(4)
# memory usage: 245.6+ KB

# %%
# using the year and the start year to filter out duplicate movies in different years and use one
genre_financial_df = genre_financial_df.loc[genre_financial_df.year == genre_financial_df.start_year]

# %%
genre_financial_df.head()
genre_financial_df.info()
# Out:
#        tconst                   original_title  start_year  \
# 0   tt0249516                       Foodfight!        2012
# 3   tt3844362                    The Overnight        2015
# 6   tt3872966                      On the Road        2013
# 10  tt0359950  The Secret Life of Walter Mitty        2013
# 11  tt0365907      A Walk Among the Tombstones        2014
#
#                      genres  Talk-Show  Game-Show  Western  Reality-TV   News  \
# 0   Action,Animation,Comedy      False      False    False       False  False
# 3            Comedy,Mystery      False      False    False       False  False
# 6               Documentary      False      False    False       False  False
# 10   Adventure,Comedy,Drama      False      False    False       False  False
# 11       Action,Crime,Drama      False      False    False       False  False
#
#     Sci-Fi  ...  Thriller  Musical  Adventure  \
# 0    False  ...     False    False      False
# 3    False  ...     False    False      False
# 6    False  ...     False    False      False
# 10   False  ...     False    False       True
# 11   False  ...     False    False      False
#
#                               movie  production_budget  domestic_gross  \
# 0                        Foodfight!           45000000               0
# 3                     The Overnight             200000         1109808
# 6                       On the Road           25000000          720828
# 10  The Secret Life of Walter Mitty           91000000        58236838
# 11      A Walk Among the Tombstones           28000000        26017685
#
#     worldwide_gross  year  net_income  net_income_ratio
# 0             73706  2012   -44926294         -0.998362
# 3           1165996  2015      965996          4.829980
# 6           9313302  2013   -15686698         -0.627468
# 10        187861183  2013    96861183          1.064409
# 11         62108587  2014    34108587          1.218164
#
# [5 rows x 38 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1379 entries, 0 to 3506
# Data columns (total 38 columns):
# tconst               1379 non-null object
# original_title       1379 non-null object
# start_year           1379 non-null int64
# genres               1379 non-null object
# Talk-Show            1379 non-null bool
# Game-Show            1379 non-null bool
# Western              1379 non-null bool
# Reality-TV           1379 non-null bool
# News                 1379 non-null bool
# Sci-Fi               1379 non-null bool
# Biography            1379 non-null bool
# Crime                1379 non-null bool
# Fantasy              1379 non-null bool
# Horror               1379 non-null bool
# Sport                1379 non-null bool
# History              1379 non-null bool
# War                  1379 non-null bool
# Action               1379 non-null bool
# Family               1379 non-null bool
# Music                1379 non-null bool
# Animation            1379 non-null bool
# Romance              1379 non-null bool
# Mystery              1379 non-null bool
# Documentary          1379 non-null bool
# Short                1379 non-null bool
# Adult                1379 non-null bool
# Comedy               1379 non-null bool
# Drama                1379 non-null bool
# Thriller             1379 non-null bool
# Musical              1379 non-null bool
# Adventure            1379 non-null bool
# movie                1379 non-null object
# production_budget    1379 non-null int64
# domestic_gross       1379 non-null int64
# worldwide_gross      1379 non-null int64
# year                 1379 non-null int32
# net_income           1379 non-null int64
# net_income_ratio     1379 non-null float64
# dtypes: bool(27), float64(1), int32(1), int64(5), object(4)
# memory usage: 160.3+ KB

# %%
genre_financial_df.genres.isna().sum() #finding the none values
# Out:
# 4

# %%
genre_financial_df.dropna(subset = ['genres'], inplace = True)

# %%
genre_financial_df = genre_financial_df.loc[(genre_financial_df.worldwide_gross != 0)]

# %%
genre_financial_df.head(100)
# Out:
#         tconst                      original_title  start_year  \
# 0    tt0249516                          Foodfight!        2012
# 3    tt3844362                       The Overnight        2015
# 6    tt3872966                         On the Road        2013
# 10   tt0359950     The Secret Life of Walter Mitty        2013
# 11   tt0365907         A Walk Among the Tombstones        2014
# 12   tt0369610                      Jurassic World        2015
# 13   tt0376136                       The Rum Diary        2011
# 14   tt0383010                   The Three Stooges        2012
# 17   tt0398286                             Tangled        2010
# 18   tt0401729                         John Carter        2012
# 20   tt0427152                 Dinner for Schmucks        2010
# 21   tt0429493                          The A-Team        2010
# 22   tt0431021                      The Possession        2012
# 23   tt0433035                          Real Steel        2011
# 24   tt0435651                           The Giver        2014
# 25   tt0435761                         Toy Story 3        2010
# 27   tt1560985                    The Devil Inside        2012
# 29   tt0443272                             Lincoln        2012
# 33   tt0443533                 The History of Love        2016
# 35   tt0448694                       Puss in Boots        2011
# 36   tt0451279                        Wonder Woman        2017
# 39   tt0453562                                  42        2013
# 40   tt0454876                          Life of Pi        2012
# 41   tt0455407                         The Crazies        2010
# 42   tt0455944                       The Equalizer        2014
# 43   tt0458339  Captain America: The First Avenger        2011
# 44   tt0458481        Sin City: A Dame to Kill For        2014
# 46   tt0464154                          Piranha 3D        2010
# 47   tt0466893                            Margaret        2011
# 49   tt0471042                         Tower Heist        2011
# ..         ...                                 ...         ...
# 120  tt0816692                        Interstellar        2014
# 121  tt0816711                         World War Z        2013
# 122  tt0817177                             Flipped        2010
# 124  tt0817230                     Valentine's Day        2010
# 125  tt0822847                              Priest        2011
# 126  tt0829150                      Dracula Untold        2014
# 127  tt0831387                            Godzilla        2014
# 129  tt0837562                  Hotel Transylvania        2012
# 132  tt0840361                            The Town        2010
# 134  tt0842926              The Kids Are All Right        2010
# 135  tt0848228                        The Avengers        2012
# 137  tt0848537                                Epic        2013
# 139  tt3231054                               Risen        2016
# 141  tt0864835               Mr. Peabody & Sherman        2014
# 142  tt0872230                     My Soul to Take        2010
# 143  tt0873886                           Red State        2011
# 144  tt0878835                         Please Give        2010
# 145  tt0879870                       Eat Pray Love        2010
# 146  tt0881320                             Sanctum        2011
# 147  tt0882977                              Snitch        2013
# 149  tt0884732                  The Wedding Ringer        2015
# 150  tt0889573                          The Switch        2010
# 151  tt0892318                   Letters to Juliet        2010
# 152  tt0892769            How to Train Your Dragon        2010
# 153  tt0892791                 Shrek Forever After        2010
# 154  tt0903624   The Hobbit: An Unexpected Journey        2012
# 155  tt0905372                           The Thing        2011
# 157  tt0918940                The Legend of Tarzan        2016
# 159  tt0935075                         Rabbit Hole        2010
# 160  tt0938283                  The Last Airbender        2010
#
#                          genres  Talk-Show  Game-Show  Western  Reality-TV  \
# 0       Action,Animation,Comedy      False      False    False       False
# 3                Comedy,Mystery      False      False    False       False
# 6                   Documentary      False      False    False       False
# 10       Adventure,Comedy,Drama      False      False    False       False
# 11           Action,Crime,Drama      False      False    False       False
# 12      Action,Adventure,Sci-Fi      False      False    False       False
# 13                 Comedy,Drama      False      False    False       False
# 14                Comedy,Family      False      False    False       False
# 17   Adventure,Animation,Comedy      False      False    False       False
# 18      Action,Adventure,Sci-Fi      False      False    False       False
# 20                       Comedy      False      False    False       False
# 21    Action,Adventure,Thriller      False      False    False       False
# 22      Horror,Mystery,Thriller      False      False    False       False
# 23          Action,Drama,Family      False      False    False       False
# 24         Drama,Romance,Sci-Fi      False      False    False       False
# 25   Adventure,Animation,Comedy      False      False    False       False
# 27                       Horror      False      False    False       False
# 29      Biography,Drama,History      False      False    False       False
# 33            Drama,Romance,War      False      False    False       False
# 35   Action,Adventure,Animation      False      False    False       False
# 36     Action,Adventure,Fantasy      False      False    False       False
# 39        Biography,Drama,Sport      False      False    False       False
# 40      Adventure,Drama,Fantasy      False      False    False       False
# 41              Horror,Thriller      False      False    False       False
# 42        Action,Crime,Thriller      False      False    False       False
# 43      Action,Adventure,Sci-Fi      False      False    False       False
# 44               Crime,Thriller      False      False    False       False
# 46                Comedy,Horror      False      False    False       False
# 47                        Drama      False      False    False       False
# 49          Action,Comedy,Crime      False      False    False       False
# ..                          ...        ...        ...      ...         ...
# 120      Adventure,Drama,Sci-Fi      False      False    False       False
# 121     Action,Adventure,Horror      False      False    False       False
# 122        Comedy,Drama,Romance      False      False    False       False
# 124              Comedy,Romance      False      False    False       False
# 125    Action,Adventure,Fantasy      False      False    False       False
# 126        Action,Drama,Fantasy      False      False    False       False
# 127     Action,Adventure,Sci-Fi      False      False    False       False
# 129     Animation,Comedy,Family      False      False    False       False
# 132        Crime,Drama,Thriller      False      False    False       False
# 134        Comedy,Drama,Romance      False      False    False       False
# 135     Action,Adventure,Sci-Fi      False      False    False       False
# 137  Adventure,Animation,Family      False      False    False       False
# 139      Action,Adventure,Drama      False      False    False       False
# 141  Adventure,Animation,Comedy      False      False    False       False
# 142     Horror,Mystery,Thriller      False      False    False       False
# 143         Action,Crime,Horror      False      False    False       False
# 144                Comedy,Drama      False      False    False       False
# 145               Drama,Romance      False      False    False       False
# 146    Adventure,Drama,Thriller      False      False    False       False
# 147       Action,Drama,Thriller      False      False    False       False
# 149                      Comedy      False      False    False       False
# 150        Comedy,Drama,Romance      False      False    False       False
# 151      Adventure,Comedy,Drama      False      False    False       False
# 152  Action,Adventure,Animation      False      False    False       False
# 153  Adventure,Animation,Comedy      False      False    False       False
# 154    Adventure,Family,Fantasy      False      False    False       False
# 155       Horror,Mystery,Sci-Fi      False      False    False       False
# 157      Action,Adventure,Drama      False      False    False       False
# 159                       Drama      False      False    False       False
# 160     Action,Adventure,Family      False      False    False       False
#
#       News  Sci-Fi  ...  Comedy  Drama  Thriller  Musical  Adventure  \
# 0    False   False  ...    True  False     False    False      False
# 3    False   False  ...    True  False     False    False      False
# 6    False   False  ...   False  False     False    False      False
# 10   False   False  ...    True   True     False    False       True
# 11   False   False  ...   False   True     False    False      False
# 12   False    True  ...   False  False     False    False       True
# 13   False   False  ...    True   True     False    False      False
# 14   False   False  ...    True  False     False    False      False
# 17   False   False  ...    True  False     False    False       True
# 18   False    True  ...   False  False     False    False       True
# 20   False   False  ...    True  False     False    False      False
# 21   False   False  ...   False  False      True    False       True
# 22   False   False  ...   False  False      True    False      False
# 23   False   False  ...   False   True     False    False      False
# 24   False    True  ...   False   True     False    False      False
# 25   False   False  ...    True  False     False    False       True
# 27   False   False  ...   False  False     False    False      False
# 29   False   False  ...   False   True     False    False      False
# 33   False   False  ...   False   True     False    False      False
# 35   False   False  ...   False  False     False    False       True
# 36   False   False  ...   False  False     False    False       True
# 39   False   False  ...   False   True     False    False      False
# 40   False   False  ...   False   True     False    False       True
# 41   False   False  ...   False  False      True    False      False
# 42   False   False  ...   False  False      True    False      False
# 43   False    True  ...   False  False     False    False       True
# 44   False   False  ...   False  False      True    False      False
# 46   False   False  ...    True  False     False    False      False
# 47   False   False  ...   False   True     False    False      False
# 49   False   False  ...    True  False     False    False      False
# ..     ...     ...  ...     ...    ...       ...      ...        ...
# 120  False    True  ...   False   True     False    False       True
# 121  False   False  ...   False  False     False    False       True
# 122  False   False  ...    True   True     False    False      False
# 124  False   False  ...    True  False     False    False      False
# 125  False   False  ...   False  False     False    False       True
# 126  False   False  ...   False   True     False    False      False
# 127  False    True  ...   False  False     False    False       True
# 129  False   False  ...    True  False     False    False      False
# 132  False   False  ...   False   True      True    False      False
# 134  False   False  ...    True   True     False    False      False
# 135  False    True  ...   False  False     False    False       True
# 137  False   False  ...   False  False     False    False       True
# 139  False   False  ...   False   True     False    False       True
# 141  False   False  ...    True  False     False    False       True
# 142  False   False  ...   False  False      True    False      False
# 143  False   False  ...   False  False     False    False      False
# 144  False   False  ...    True   True     False    False      False
# 145  False   False  ...   False   True     False    False      False
# 146  False   False  ...   False   True      True    False       True
# 147  False   False  ...   False   True      True    False      False
# 149  False   False  ...    True  False     False    False      False
# 150  False   False  ...    True   True     False    False      False
# 151  False   False  ...    True   True     False    False       True
# 152  False   False  ...   False  False     False    False       True
# 153  False   False  ...    True  False     False    False       True
# 154  False   False  ...   False  False     False    False       True
# 155  False    True  ...   False  False     False    False      False
# 157  False   False  ...   False   True     False    False       True
# 159  False   False  ...   False   True     False    False      False
# 160  False   False  ...   False  False     False    False       True
#
#                                   movie  production_budget  domestic_gross  \
# 0                            Foodfight!           45000000               0
# 3                         The Overnight             200000         1109808
# 6                           On the Road           25000000          720828
# 10      The Secret Life of Walter Mitty           91000000        58236838
# 11          A Walk Among the Tombstones           28000000        26017685
# 12                       Jurassic World          215000000       652270625
# 13                        The Rum Diary           45000000        13109815
# 14                    The Three Stooges           30000000        44338224
# 17                              Tangled          260000000       200821936
# 18                          John Carter          275000000        73058679
# 20                  Dinner for Schmucks           69000000        73026337
# 21                           The A-Team          110000000        77222099
# 22                       The Possession           14000000        49130588
# 23                           Real Steel          110000000        85463309
# 24                            The Giver           25000000        45090374
# 25                          Toy Story 3          200000000       415004880
# 27                     The Devil Inside            1000000        53262945
# 29                              Lincoln           65000000       182207973
# 33                  The History of Love           20000000               0
# 35                        Puss in Boots          130000000       149260504
# 36                         Wonder Woman          150000000       412563408
# 39                                   42           31000000        95020213
# 40                           Life of Pi          120000000       124987022
# 41                          The Crazies           19000000        39123589
# 42                        The Equalizer           55000000       101530738
# 43   Captain America: The First Avenger          140000000       176654505
# 44         Sin City: A Dame to Kill For           65000000        13757804
# 46                           Piranha 3D           24000000        25003155
# 47                             Margaret           14000000           47185
# 49                          Tower Heist           85000000        78046570
# ..                                  ...                ...             ...
# 120                        Interstellar          165000000       188017894
# 121                         World War Z          190000000       202359711
# 122                             Flipped           14000000         1755212
# 124                     Valentine's Day           52000000       110485654
# 125                              Priest           60000000        29136626
# 126                      Dracula Untold           70000000        55991880
# 127                            Godzilla          160000000       200676069
# 129                  Hotel Transylvania           85000000       148313048
# 132                            The Town           37000000        92186262
# 134              The Kids Are All Right            4000000        20811365
# 135                        The Avengers          225000000       623279547
# 137                                Epic          100000000       107518682
# 139                               Risen           20000000        36880033
# 141               Mr. Peabody & Sherman          145000000       111506430
# 142                     My Soul to Take           25000000        14744435
# 143                           Red State            4000000         1065429
# 144                         Please Give            3000000         4033574
# 145                       Eat Pray Love           60000000        80574010
# 146                             Sanctum           30000000        23209310
# 147                              Snitch           15000000        42930462
# 149                  The Wedding Ringer           23000000        64460211
# 150                          The Switch           19000000        27758465
# 151                   Letters to Juliet           30000000        53032453
# 152            How to Train Your Dragon          165000000       217581232
# 153                 Shrek Forever After          165000000       238736787
# 154   The Hobbit: An Unexpected Journey          250000000       303003568
# 155                           The Thing           38000000        16999934
# 157                The Legend of Tarzan          180000000       126643061
# 159                         Rabbit Hole            5000000         2229058
# 160                  The Last Airbender          150000000       131772187
#
#      worldwide_gross  year
# 0              73706  2012
# 3            1165996  2015
# 6            9313302  2013
# 10         187861183  2013
# 11          62108587  2014
# 12        1648854864  2015
# 13          21544732  2011
# 14          54052249  2012
# 17         586477240  2010
# 18         282778100  2012
# 20          86796502  2010
# 21         177241171  2010
# 22          82925064  2012
# 23         263880341  2011
# 24          66540205  2014
# 25        1068879522  2010
# 27         101759490  2012
# 29         273346281  2012
# 33            476624  2016
# 35         554987477  2011
# 36         821133378  2017
# 39          97470701  2013
# 40         620912003  2012
# 41          56445534  2010
# 42         192903624  2014
# 43         370569776  2011
# 44          40650842  2014
# 46          83660160  2010
# 47            623292  2011
# 49         150422946  2011
# ..               ...   ...
# 120        666379375  2014
# 121        531514650  2013
# 122          4289993  2010
# 124        217569328  2010
# 125         84154026  2011
# 126        220241723  2014
# 127        529076069  2014
# 129        378505812  2012
# 132        152566881  2010
# 134         36275469  2010
# 135       1517935897  2012
# 137        262794441  2013
# 139         46255763  2016
# 141        269806430  2014
# 142         16727470  2010
# 143          1983596  2011
# 144          4570178  2010
# 145        206598789  2010
# 146        108957098  2011
# 147         57907734  2013
# 149         80171596  2015
# 150         49858465  2010
# 151         82148538  2010
# 152        494870992  2010
# 153        756244673  2010
# 154       1017003568  2012
# 155         27573078  2011
# 157        348902025  2016
# 159          6205034  2010
# 160        319713881  2010
#
# [100 rows x 36 columns]

# %%
# looking for duplicate values
display(genre_financial_df[genre_financial_df.duplicated(
    subset=['original_title', 'year'], keep=False)])
# setting panda code settin gto display all row values without truncation
pd.options.display.max_rows = 77
duplicate_indices = [210, 216, 225, 276, 456, 505, 540, 700, 714, 781,
                     805, 1012, 1013, 1079, 1244, 1261, 1274, 1390, 1499,
                     1500, 1532, 1704, 1732, 1800, 1833, 1904, 2055, 2061,
                     2165, 2230, 2442, 2443, 2563, 2657, 2662, 2664, 2823,
                     2831, 2925, 3037, 3176]
# Out:
#           tconst       original_title  start_year  \
# 209   tt10013288          The Promise        2017
# 210    tt4192918          The Promise        2017
# 216    tt9889072          The Promise        2017
# 221    tt1661199           Cinderella        2015
# 225    tt5089556           Cinderella        2015
# 272    tt1014759  Alice in Wonderland        2010
# 276    tt2049386  Alice in Wonderland        2010
# 455    tt2380307                 Coco        2017
# 456    tt7002100                 Coco        2017
# 504    tt4786282           Lights Out        2016
# 505    tt5328340           Lights Out        2016
# 537    tt1126590             Big Eyes        2014
# 538    tt4317898             Big Eyes        2014
# 539    tt1126591            Burlesque        2010
# 540    tt1586713            Burlesque        2010
# 698    tt1267297             Hercules        2014
# 700    tt3985956             Hercules        2014
# 713    tt1274300          The Tempest        2010
# 714    tt1683003          The Tempest        2010
# 781    tt1327709                Cyrus        2010
# 782    tt1336617                Cyrus        2010
# 805    tt3059814           Redemption        2013
# 806    tt3279418           Redemption        2013
# 1008   tt4218696             The Wall        2017
# 1012   tt6845582             The Wall        2017
# 1013   tt7578246             The Wall        2017
# 1078   tt3387542           The Forest        2016
# 1079   tt4982356           The Forest        2016
# 1242   tt1600195            Abduction        2011
# 1244   tt2447982            Abduction        2011
# 1260   tt3567288            The Visit        2015
# 1261   tt3833746            The Visit        2015
# 1273   tt1610996             Absentia        2011
# 1274   tt7501544             Absentia        2011
# 1389   tt1655442           The Artist        2011
# 1390   tt1825978           The Artist        2011
# 1498   tt1714210              Weekend        2011
# 1499   tt1791679              Weekend        2011
# 1500   tt1910670              Weekend        2011
# 1531   tt2404311           The Family        2013
# 1532   tt4155318           The Family        2013
# 1703   tt6772950        Truth or Dare        2018
# 1704   tt6869948        Truth or Dare        2018
# 1731   tt1850457              Sisters        2015
# 1732   tt4793074              Sisters        2015
# 1799   tt1895587            Spotlight        2015
# 1800   tt7785302            Spotlight        2015
# 1832   tt1922685              Phantom        2013
# 1833   tt3088580              Phantom        2013
# 1904   tt3231362              Destiny        2014
# 1905   tt3523348              Destiny        2014
# 2028   tt2224026                 Home        2015
# 2055   tt5121236                 Home        2015
# 2061   tt5884960                 Home        2015
# 2165   tt2159988             The Walk        2015
# 2166   tt3488710             The Walk        2015
# 2229   tt2205401             Addicted        2014
# 2230   tt3435418             Addicted        2014
# 2442   tt3532296                  Joe        2014
# 2443   tt3614128                  Joe        2014
# 2563   tt3381068               Legend        2015
# 2569   tt3569230               Legend        2015
# 2656   tt5804314   Let There Be Light        2017
# 2657   tt6184774   Let There Be Light        2017
# 2662   tt2943946           The Circle        2017
# 2663   tt4287320           The Circle        2017
# 2664   tt6954894           The Circle        2017
# 2823   tt3262990       Brotherly Love        2015
# 2824   tt3787742       Brotherly Love        2015
# 2829   tt3276924                Heist        2015
# 2831   tt5112932                Heist        2015
# 2923   tt3530002     The Night Before        2015
# 2925   tt6353886     The Night Before        2015
# 3036   tt3881784             Stronger        2017
# 3037   tt5738152             Stronger        2017
# 3175   tt4645330               Denial        2016
# 3176   tt5897002               Denial        2016
#
#                            genres  Talk-Show  Game-Show  Western  Reality-TV  \
# 209                         Drama      False      False    False       False
# 210                        Comedy      False      False    False       False
# 216                         Drama      False      False    False       False
# 221          Drama,Family,Fantasy      False      False    False       False
# 225                       Fantasy      False      False    False       False
# 272      Adventure,Family,Fantasy      False      False    False       False
# 276               Fantasy,Musical      False      False    False       False
# 455    Adventure,Animation,Comedy      False      False    False       False
# 456                        Horror      False      False    False       False
# 504          Drama,Horror,Mystery      False      False    False       False
# 505                   Documentary      False      False    False       False
# 537         Biography,Crime,Drama      False      False    False       False
# 538                   Documentary      False      False    False       False
# 539           Drama,Music,Musical      False      False    False       False
# 540                         Drama      False      False    False       False
# 698      Action,Adventure,Fantasy      False      False    False       False
# 700                        Comedy      False      False    False       False
# 713          Comedy,Drama,Fantasy      False      False    False       False
# 714                         Drama      False      False    False       False
# 781          Crime,Horror,Mystery      False      False    False       False
# 782          Comedy,Drama,Romance      False      False    False       False
# 805          Drama,Music,Thriller      False      False    False       False
# 806        Drama,Mystery,Thriller      False      False    False       False
# 1008        Action,Drama,Thriller      False      False    False       False
# 1012                  Documentary      False      False    False       False
# 1013                  Documentary      False      False    False       False
# 1078      Horror,Mystery,Thriller      False      False    False       False
# 1079         Drama,Fantasy,Horror      False      False    False       False
# 1242      Action,Mystery,Thriller      False      False    False       False
# 1244              Horror,Thriller      False      False    False       False
# 1260      Horror,Mystery,Thriller      False      False    False       False
# 1261                  Documentary      False      False    False       False
# 1273         Drama,Horror,Mystery      False      False    False       False
# 1274                       Sci-Fi      False      False    False       False
# 1389         Comedy,Drama,Romance      False      False    False       False
# 1390                     Thriller      False      False    False       False
# 1498                Drama,Romance      False      False    False       False
# 1499          Action,Comedy,Crime      False      False    False       False
# 1500                 Comedy,Drama      False      False    False       False
# 1531        Comedy,Crime,Thriller      False      False    False       False
# 1532           Comedy,Crime,Drama      False      False    False       False
# 1703              Horror,Thriller      False      False    False       False
# 1704         Comedy,Drama,Romance      False      False    False       False
# 1731                       Comedy      False      False    False       False
# 1732  Biography,Documentary,Music      False      False    False       False
# 1799                  Crime,Drama      False      False    False       False
# 1800                        Drama      False      False    False       False
# 1832       Drama,History,Thriller      False      False    False       False
# 1833                        Drama      False      False    False       False
# 1904      Adventure,Comedy,Family      False      False    False       False
# 1905          Drama,Music,Romance      False      False    False       False
# 2028   Adventure,Animation,Comedy      False      False    False       False
# 2055                  Documentary      False      False    False       False
# 2061                  Documentary      False      False    False       False
# 2165               Crime,Thriller      False      False    False       False
# 2166    Adventure,Biography,Drama      False      False    False       False
# 2229               Drama,Thriller      False      False    False       False
# 2230            Documentary,Music      False      False    False       False
# 2442                  Documentary      False      False    False       False
# 2443        Biography,Documentary      False      False    False       False
# 2563                       Horror      False      False    False       False
# 2569        Biography,Crime,Drama      False      False    False       False
# 2656                        Drama      False      False    False       False
# 2657                  Documentary      False      False    False       False
# 2662        Drama,Horror,Thriller      False      False    False       False
# 2663        Drama,Sci-Fi,Thriller      False      False    False       False
# 2664                  Documentary      False      False    False       False
# 2823                        Drama      False      False    False       False
# 2824                       Horror      False      False    False       False
# 2829        Action,Crime,Thriller      False      False    False       False
# 2831                       Action      False      False    False       False
# 2923     Adventure,Comedy,Fantasy      False      False    False       False
# 2925                  Documentary      False      False    False       False
# 3036              Biography,Drama      False      False    False       False
# 3037                        Drama      False      False    False       False
# 3175              Biography,Drama      False      False    False       False
# 3176                  Documentary      False      False    False       False
#
#        News  Sci-Fi  ...  Thriller  Musical  Adventure                movie  \
# 209   False   False  ...     False    False      False          The Promise
# 210   False   False  ...     False    False      False          The Promise
# 216   False   False  ...     False    False      False          The Promise
# 221   False   False  ...     False    False      False           Cinderella
# 225   False   False  ...     False    False      False           Cinderella
# 272   False   False  ...     False    False       True  Alice in Wonderland
# 276   False   False  ...     False     True      False  Alice in Wonderland
# 455   False   False  ...     False    False       True                 Coco
# 456   False   False  ...     False    False      False                 Coco
# 504   False   False  ...     False    False      False           Lights Out
# 505   False   False  ...     False    False      False           Lights Out
# 537   False   False  ...     False    False      False             Big Eyes
# 538   False   False  ...     False    False      False             Big Eyes
# 539   False   False  ...     False     True      False            Burlesque
# 540   False   False  ...     False    False      False            Burlesque
# 698   False   False  ...     False    False       True             Hercules
# 700   False   False  ...     False    False      False             Hercules
# 713   False   False  ...     False    False      False          The Tempest
# 714   False   False  ...     False    False      False          The Tempest
# 781   False   False  ...     False    False      False                Cyrus
# 782   False   False  ...     False    False      False                Cyrus
# 805   False   False  ...      True    False      False           Redemption
# 806   False   False  ...      True    False      False           Redemption
# 1008  False   False  ...      True    False      False             The Wall
# 1012  False   False  ...     False    False      False             The Wall
# 1013  False   False  ...     False    False      False             The Wall
# 1078  False   False  ...      True    False      False           The Forest
# 1079  False   False  ...     False    False      False           The Forest
# 1242  False   False  ...      True    False      False            Abduction
# 1244  False   False  ...      True    False      False            Abduction
# 1260  False   False  ...      True    False      False            The Visit
# 1261  False   False  ...     False    False      False            The Visit
# 1273  False   False  ...     False    False      False             Absentia
# 1274  False    True  ...     False    False      False             Absentia
# 1389  False   False  ...     False    False      False           The Artist
# 1390  False   False  ...      True    False      False           The Artist
# 1498  False   False  ...     False    False      False              Weekend
# 1499  False   False  ...     False    False      False              Weekend
# 1500  False   False  ...     False    False      False              Weekend
# 1531  False   False  ...      True    False      False           The Family
# 1532  False   False  ...     False    False      False           The Family
# 1703  False   False  ...      True    False      False        Truth or Dare
# 1704  False   False  ...     False    False      False        Truth or Dare
# 1731  False   False  ...     False    False      False              Sisters
# 1732  False   False  ...     False    False      False              Sisters
# 1799  False   False  ...     False    False      False            Spotlight
# 1800  False   False  ...     False    False      False            Spotlight
# 1832  False   False  ...      True    False      False              Phantom
# 1833  False   False  ...     False    False      False              Phantom
# 1904  False   False  ...     False    False       True              Destiny
# 1905  False   False  ...     False    False      False              Destiny
# 2028  False   False  ...     False    False       True                 Home
# 2055  False   False  ...     False    False      False                 Home
# 2061  False   False  ...     False    False      False                 Home
# 2165  False   False  ...      True    False      False             The Walk
# 2166  False   False  ...     False    False       True             The Walk
# 2229  False   False  ...      True    False      False             Addicted
# 2230  False   False  ...     False    False      False             Addicted
# 2442  False   False  ...     False    False      False                  Joe
# 2443  False   False  ...     False    False      False                  Joe
# 2563  False   False  ...     False    False      False               Legend
# 2569  False   False  ...     False    False      False               Legend
# 2656  False   False  ...     False    False      False   Let There Be Light
# 2657  False   False  ...     False    False      False   Let There Be Light
# 2662  False   False  ...      True    False      False           The Circle
# 2663  False    True  ...      True    False      False           The Circle
# 2664  False   False  ...     False    False      False           The Circle
# 2823  False   False  ...     False    False      False       Brotherly Love
# 2824  False   False  ...     False    False      False       Brotherly Love
# 2829  False   False  ...      True    False      False                Heist
# 2831  False   False  ...     False    False      False                Heist
# 2923  False   False  ...     False    False       True     The Night Before
# 2925  False   False  ...     False    False      False     The Night Before
# 3036  False   False  ...     False    False      False             Stronger
# 3037  False   False  ...     False    False      False             Stronger
# 3175  False   False  ...     False    False      False               Denial
# 3176  False   False  ...     False    False      False               Denial
#
#       production_budget  domestic_gross  worldwide_gross  year  net_income  \
# 209            90000000         8224288         10551417  2017   -79448583
# 210            90000000         8224288         10551417  2017   -79448583
# 216            90000000         8224288         10551417  2017   -79448583
# 221            95000000       201151353        534551353  2015   439551353
# 225            95000000       201151353        534551353  2015   439551353
# 272           200000000       334191110       1025491110  2010   825491110
# 276           200000000       334191110       1025491110  2010   825491110
# 455           175000000       209726015        798008101  2017   623008101
# 456           175000000       209726015        798008101  2017   623008101
# 504             5000000        67268835        148806510  2016   143806510
# 505             5000000        67268835        148806510  2016   143806510
# 537            10000000        14482031         27317872  2014    17317872
# 538            10000000        14482031         27317872  2014    17317872
# 539            55000000        39440655         90552675  2010    35552675
# 540            55000000        39440655         90552675  2010    35552675
# 698           100000000        72688614        243388614  2014   143388614
# 700           100000000        72688614        243388614  2014   143388614
# 713            20000000          277943           277943  2010   -19722057
# 714            20000000          277943           277943  2010   -19722057
# 781             7000000         7468936         10062896  2010     3062896
# 782             7000000         7468936         10062896  2010     3062896
# 805            23000000           36686         13593473  2013    -9406527
# 806            23000000           36686         13593473  2013    -9406527
# 1008            3000000         1803064          4495262  2017     1495262
# 1012            3000000         1803064          4495262  2017     1495262
# 1013            3000000         1803064          4495262  2017     1495262
# 1078           10000000        26594261         40749230  2016    30749230
# 1079           10000000        26594261         40749230  2016    30749230
# 1242           35000000        28087155         86648359  2011    51648359
# 1244           35000000        28087155         86648359  2011    51648359
# 1260            5000000        65206105         98677816  2015    93677816
# 1261            5000000        65206105         98677816  2015    93677816
# 1273              70000               0             8555  2011      -61445
# 1274              70000               0             8555  2011      -61445
# 1389           16000000        44667095        128256712  2011   112256712
# 1390           16000000        44667095        128256712  2011   112256712
# 1498             190000          484592          1577585  2011     1387585
# 1499             190000          484592          1577585  2011     1387585
# 1500             190000          484592          1577585  2011     1387585
# 1531           30000000        36918811         51078541  2013    21078541
# 1532           30000000        36918811         51078541  2013    21078541
# 1703            3500000        41411015         95127344  2018    91627344
# 1704            3500000        41411015         95127344  2018    91627344
# 1731           30000000        87044645        106030660  2015    76030660
# 1732           30000000        87044645        106030660  2015    76030660
# 1799           20000000        45055776         92088460  2015    72088460
# 1800           20000000        45055776         92088460  2015    72088460
# 1832           18000000         1034589          1199510  2013   -16800490
# 1833           18000000         1034589          1199510  2013   -16800490
# 1904             750000               0              450  2014     -749550
# 1905             750000               0              450  2014     -749550
# 2028          130000000       177397510        385997896  2015   255997896
# 2055          130000000       177397510        385997896  2015   255997896
# 2061          130000000       177397510        385997896  2015   255997896
# 2165           35000000        10161183         61492104  2015    26492104
# 2166           35000000        10161183         61492104  2015    26492104
# 2229            5000000        17390770         17499242  2014    12499242
# 2230            5000000        17390770         17499242  2014    12499242
# 2442            4000000          373375           373375  2014    -3626625
# 2443            4000000          373375           373375  2014    -3626625
# 2563           25000000         1872994         42425450  2015    17425450
# 2569           25000000         1872994         42425450  2015    17425450
# 2656            3000000         7233471          7241309  2017     4241309
# 2657            3000000         7233471          7241309  2017     4241309
# 2662           18000000        20497844         40651864  2017    22651864
# 2663           18000000        20497844         40651864  2017    22651864
# 2664           18000000        20497844         40651864  2017    22651864
# 2823            1900000          478595           478595  2015    -1421405
# 2824            1900000          478595           478595  2015    -1421405
# 2829            8900000           50136          3324131  2015    -5575869
# 2831            8900000           50136          3324131  2015    -5575869
# 2923           25000000        43035725         52427346  2015    27427346
# 2925           25000000        43035725         52427346  2015    27427346
# 3036           30000000         4211129          8786752  2017   -21213248
# 3037           30000000         4211129          8786752  2017   -21213248
# 3175           10000000         4073448          9263940  2016     -736060
# 3176           10000000         4073448          9263940  2016     -736060
#
#       net_income_ratio
# 209          -0.882762
# 210          -0.882762
# 216          -0.882762
# 221           4.626856
# 225           4.626856
# 272           4.127456
# 276           4.127456
# 455           3.560046
# 456           3.560046
# 504          28.761302
# 505          28.761302
# 537           1.731787
# 538           1.731787
# 539           0.646412
# 540           0.646412
# 698           1.433886
# 700           1.433886
# 713          -0.986103
# 714          -0.986103
# 781           0.437557
# 782           0.437557
# 805          -0.408979
# 806          -0.408979
# 1008          0.498421
# 1012          0.498421
# 1013          0.498421
# 1078          3.074923
# 1079          3.074923
# 1242          1.475667
# 1244          1.475667
# 1260         18.735563
# 1261         18.735563
# 1273         -0.877786
# 1274         -0.877786
# 1389          7.016044
# 1390          7.016044
# 1498          7.303079
# 1499          7.303079
# 1500          7.303079
# 1531          0.702618
# 1532          0.702618
# 1703         26.179241
# 1704         26.179241
# 1731          2.534355
# 1732          2.534355
# 1799          3.604423
# 1800          3.604423
# 1832         -0.933361
# 1833         -0.933361
# 1904         -0.999400
# 1905         -0.999400
# 2028          1.969215
# 2055          1.969215
# 2061          1.969215
# 2165          0.756917
# 2166          0.756917
# 2229          2.499848
# 2230          2.499848
# 2442         -0.906656
# 2443         -0.906656
# 2563          0.697018
# 2569          0.697018
# 2656          1.413770
# 2657          1.413770
# 2662          1.258437
# 2663          1.258437
# 2664          1.258437
# 2823         -0.748108
# 2824         -0.748108
# 2829         -0.626502
# 2831         -0.626502
# 2923          1.097094
# 2925          1.097094
# 3036         -0.707108
# 3037         -0.707108
# 3175         -0.073606
# 3176         -0.073606
#
# [77 rows x 38 columns]

# %%
#removing the duplicates
genre_financial_df.drop(index = duplicate_indices, inplace = True)

# %%
#creating the net_income column
genre_financial_df['net_income'] = genre_financial_df['worldwide_gross'] - genre_financial_df['production_budget']

# %%
#creating the net_income_ratio
genre_financial_df['net_income_ratio'] = genre_financial_df['net_income'] / genre_financial_df['production_budget']

# %%
genre_financial_df.head()
# Out:
#        tconst                   original_title  start_year  \
# 0   tt0249516                       Foodfight!        2012
# 3   tt3844362                    The Overnight        2015
# 6   tt3872966                      On the Road        2013
# 10  tt0359950  The Secret Life of Walter Mitty        2013
# 11  tt0365907      A Walk Among the Tombstones        2014
#
#                      genres  Talk-Show  Game-Show  Western  Reality-TV   News  \
# 0   Action,Animation,Comedy      False      False    False       False  False
# 3            Comedy,Mystery      False      False    False       False  False
# 6               Documentary      False      False    False       False  False
# 10   Adventure,Comedy,Drama      False      False    False       False  False
# 11       Action,Crime,Drama      False      False    False       False  False
#
#     Sci-Fi  ...  Thriller  Musical  Adventure  \
# 0    False  ...     False    False      False
# 3    False  ...     False    False      False
# 6    False  ...     False    False      False
# 10   False  ...     False    False       True
# 11   False  ...     False    False      False
#
#                               movie  production_budget  domestic_gross  \
# 0                        Foodfight!           45000000               0
# 3                     The Overnight             200000         1109808
# 6                       On the Road           25000000          720828
# 10  The Secret Life of Walter Mitty           91000000        58236838
# 11      A Walk Among the Tombstones           28000000        26017685
#
#     worldwide_gross  year  net_income  net_income_ratio
# 0             73706  2012   -44926294         -0.998362
# 3           1165996  2015      965996          4.829980
# 6           9313302  2013   -15686698         -0.627468
# 10        187861183  2013    96861183          1.064409
# 11         62108587  2014    34108587          1.218164
#
# [5 rows x 38 columns]

# %%
all_genres
# Out:
# ['Talk-Show',
#  'Game-Show',
#  'Western',
#  'Reality-TV',
#  'News',
#  'Sci-Fi',
#  'Biography',
#  'Crime',
#  'Fantasy',
#  'Horror',
#  'Sport',
#  'History',
#  'War',
#  'Action',
#  'Family',
#  'Music',
#  'Animation',
#  'Romance',
#  'Mystery',
#  'Documentary',
#  'Short',
#  'Adult',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Musical',
#  'Adventure']

# %%
# aggregated information on genres and budget
describe_genres=[]

for genre in all_genres:
    #We will add financial data in case of every genre, collected in the following list:
    describe_genre = []
    describe_genre.append(genre)
    #add the number of the films listed in that 
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'production_budget'].count())
    #add production budget mean
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'production_budget'].mean())
    #add production budget median
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'production_budget'].median())
    #add net_income mean
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'net_income'].mean())
    #add production budget median
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'net_income'].median())
    #add net income ratio mean
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'net_income_ratio'].mean())
    #add production budget median
    describe_genre.append(genre_financial_df.loc[genre_financial_df[genre], 'net_income_ratio'].median())
    describe_genres.append(describe_genre)
    
describe_genres_df = pd.DataFrame(describe_genres, columns=['genre', 'count', 'production_budget_mean',
                                                           'production_budget_median', 'net_income_mean',
                                                           'net_income_median', 'net_income_ratio_mean', 
                                                           'net_income_ratio_median'])
len(describe_genres_df)
# Out:
# 27

# %%
# removed genres with 0 entries
describe_genres_df = describe_genres_df.loc[describe_genres_df['count'] > 0]
# data will be in $ million
describe_genres_df.iloc[:, 2:6] = describe_genres_df.iloc[:, 2:6]/1000000
describe_genres_df.iloc[:, 2:] = describe_genres_df.iloc[:, 2:].applymap(
    lambda x: float(f'{x:.2f}'))
describe_genres_df
# Out:
#           genre  count  production_budget_mean  production_budget_median  \
# 2       Western      9                   63.42                      35.0
# 5        Sci-Fi    117                   96.38                      90.0
# 6     Biography    128                   26.57                      20.0
# 7         Crime    215                   32.75                      29.0
# 8       Fantasy    113                   86.60                      60.0
# 9        Horror    147                   19.88                      10.0
# 10        Sport     33                   24.81                      18.0
# 11      History     38                   35.66                      25.0
# 12          War     17                   27.78                      20.0
# 13       Action    402                   81.97                      60.0
# 14       Family     85                   69.16                      40.0
# 15        Music     47                   17.34                      15.0
# 16    Animation     96                   98.35                      85.0
# 17      Romance    178                   22.77                      17.0
# 18      Mystery    111                   26.54                      14.0
# 19  Documentary     31                   11.67                       2.5
# 22       Comedy    473                   41.61                      28.0
# 23        Drama    658                   28.35                      18.0
# 24     Thriller    229                   34.98                      21.0
# 25      Musical      7                   54.99                      55.0
# 26    Adventure    326                  106.80                     100.0
#
#     net_income_mean  net_income_median  net_income_ratio_mean  \
# 2             64.49              -2.24                   0.88
# 5            259.66             128.56                   2.86
# 6             55.85              18.40                   2.45
# 7             47.45              18.58                   1.28
# 8            161.82              49.68                   2.27
# 9             58.69              28.99                   9.77
# 10            28.27              14.22                   1.16
# 11            50.10              15.62                   1.57
# 12            30.57              -0.90                   0.75
# 13           166.52              63.71                   1.77
# 14           135.13              55.23                   1.79
# 15            58.11              11.00                   2.55
# 16           287.54             202.47                   2.81
# 17            47.02              18.40                   2.63
# 18            72.26              41.56                   9.80
# 19            15.53               1.65                   1.93
# 22            99.38              35.76                   2.30
# 23            50.25              15.10                   2.42
# 24            85.82              33.87                   6.03
# 25           209.13              35.55                   2.03
# 26           250.11             134.81                   2.21
#
#     net_income_ratio_median
# 2                     -0.05
# 5                      1.97
# 6                      0.87
# 7                      0.72
# 8                      1.23
# 9                      2.04
# 10                     0.57
# 11                     0.88
# 12                    -0.11
# 13                     1.24
# 14                     1.14
# 15                     1.09
# 16                     2.00
# 17                     1.35
# 18                     2.74
# 19                     0.94
# 22                     1.50
# 23                     0.98
# 24                     1.48
# 25                     0.65
# 26                     1.73

# %%
describe_genres_df.sort_values(
    by='net_income_median', inplace=True, ascending=True)
describe_genres_df
# Out:
#           genre  count  production_budget_mean  production_budget_median  \
# 2       Western      9                   63.42                      35.0
# 12          War     17                   27.78                      20.0
# 19  Documentary     31                   11.67                       2.5
# 15        Music     47                   17.34                      15.0
# 10        Sport     33                   24.81                      18.0
# 23        Drama    658                   28.35                      18.0
# 11      History     38                   35.66                      25.0
# 6     Biography    128                   26.57                      20.0
# 17      Romance    178                   22.77                      17.0
# 7         Crime    215                   32.75                      29.0
# 9        Horror    147                   19.88                      10.0
# 24     Thriller    229                   34.98                      21.0
# 25      Musical      7                   54.99                      55.0
# 22       Comedy    473                   41.61                      28.0
# 18      Mystery    111                   26.54                      14.0
# 8       Fantasy    113                   86.60                      60.0
# 14       Family     85                   69.16                      40.0
# 13       Action    402                   81.97                      60.0
# 5        Sci-Fi    117                   96.38                      90.0
# 26    Adventure    326                  106.80                     100.0
# 16    Animation     96                   98.35                      85.0
#
#     net_income_mean  net_income_median  net_income_ratio_mean  \
# 2             64.49              -2.24                   0.88
# 12            30.57              -0.90                   0.75
# 19            15.53               1.65                   1.93
# 15            58.11              11.00                   2.55
# 10            28.27              14.22                   1.16
# 23            50.25              15.10                   2.42
# 11            50.10              15.62                   1.57
# 6             55.85              18.40                   2.45
# 17            47.02              18.40                   2.63
# 7             47.45              18.58                   1.28
# 9             58.69              28.99                   9.77
# 24            85.82              33.87                   6.03
# 25           209.13              35.55                   2.03
# 22            99.38              35.76                   2.30
# 18            72.26              41.56                   9.80
# 8            161.82              49.68                   2.27
# 14           135.13              55.23                   1.79
# 13           166.52              63.71                   1.77
# 5            259.66             128.56                   2.86
# 26           250.11             134.81                   2.21
# 16           287.54             202.47                   2.81
#
#     net_income_ratio_median
# 2                     -0.05
# 12                    -0.11
# 19                     0.94
# 15                     1.09
# 10                     0.57
# 23                     0.98
# 11                     0.88
# 6                      0.87
# 17                     1.35
# 7                      0.72
# 9                      2.04
# 24                     1.48
# 25                     0.65
# 22                     1.50
# 18                     2.74
# 8                      1.23
# 14                     1.14
# 13                     1.24
# 5                      1.97
# 26                     1.73
# 16                     2.00

# %%
sns.set(style="whitegrid")
df = describe_genres_df.set_index('genre')
df = df.sort_values(by = 'net_income_median')
fig = plt.figure(figsize = (15,10))
ax = fig.add_subplot(111)
ax2 = ax.twinx()
width = 1
df.net_income_median.plot(kind = 'barh', color = 'green', ax = ax, width = width, position = 0, alpha = .5)
df.production_budget_median.plot(kind = 'barh', color = 'purple', ax = ax2, width = width, position = 0, alpha = .5)
plt.title('Net Income Median and Budget Median in Different Genres from 2010-2018\n', fontsize = 30)
plt.style.use('ggplot')
ax.set_ylabel('Genres', fontsize = 25)
ax2.set_ylabel(' ')
ax.set_xlabel('$M Dollars', fontsize = 25)
fig.savefig('fig_2_Income Ratio.jpg')
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize = 17)
ax2.get_yaxis().set_visible(False)
plt.show()
# Out:
# Text(0.5, 1.0, 'Net Income Median and Budget Median in different Genres from 2010-2018\n')
# Text(0, 0.5, 'Genres')
# Text(0, 0.5, ' ')
# Text(0.5, 0, '$M Dollars')

# %%
df = describe_genres_df.reset_index()

# %%
df = df.sort_values(by = 'net_income_ratio_median', ascending = False)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))
color_palette_list = ['#009ACD', '#ADD8E6',
                      '#63D1F4', '#0EBFE9', '#C1F0F6', '#0099CC']
ax = sns.barplot(data=df, y="genre",
                 x="net_income_ratio_median", palette="GnBu_d")

plt.title('\nNet Income Ratio Median in Different Genres from 2010-2018\n', fontsize=25)
plt.xlim(-0.2, None)
ax.set_xlabel('Net Income Ratio', fontsize=15)
ax.set_ylabel('Genres', fontsize=25)
fig.savefig('fig_2_Income Ratio_Median.jpg')
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15);

# %%
sns.set(style="white", context="talk")
rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

# Generate some sequential data
x = np.array(list("ABCDEFGHIJ"))
y1 = np.arange(1, 11)
sns.barplot(x=x, y=y1, palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Sequential")

# Center the data to make it diverging
y2 = y1 - 5.5
sns.barplot(x=x, y=y2, palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, len(y1), replace=False)
sns.barplot(x=x, y=y3, palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2);
